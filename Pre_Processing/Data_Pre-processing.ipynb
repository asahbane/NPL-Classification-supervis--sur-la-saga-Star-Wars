# %% [markdown]
# # Pre-processing

# %%
from func import *

# %% [markdown]
# ## A New Hope

# %%
## impotation des données
df1 = pd.read_csv(getpath(4)) 
df1
# Out:
#             Name                                             parole
# 0       THREEPIO  Did you hear that? They've shut down the main ...
# 1       THREEPIO                                      We're doomed!
# 2       THREEPIO  There'll be no escape for the Princess this time.
# 3       THREEPIO                                       What's that?
# 4       THREEPIO  I should have known better than to trust the l...
# ...          ...                                                ...
# 997         LUKE                                            Oh, no!
# 998     THREEPIO  Oh, my! Artoo! Can you hear me? Say something!...
# 999   TECHNICIAN               We'll get to work on him right away.
# 1000    THREEPIO  You must repair him! Sir, if any of my circuit...
# 1001        LUKE                                He'll be all right.
#
# [1002 rows x 2 columns]

# %%
D1 = magic2(df1)
D1
# Out:
#             Name                                             parole  \
# 0       THREEPIO  Did you hear that? They've shut down the main ...
# 1       THREEPIO                                      We're doomed!
# 2       THREEPIO  There'll be no escape for the Princess this time.
# 3       THREEPIO                                       What's that?
# 4       THREEPIO  I should have known better than to trust the l...
# ...          ...                                                ...
# 997         LUKE                                            Oh, no!
# 998     THREEPIO  Oh, my! Artoo! Can you hear me? Say something!...
# 999   TECHNICIAN               We'll get to work on him right away.
# 1000    THREEPIO  You must repair him! Sir, if any of my circuit...
# 1001        LUKE                                He'll be all right.
#
#                                         paroles_traités
# 0         hear shut main reactor destroyed sure madness
# ...

# %% [markdown]
# ## indicateurs statistiques

# %% [markdown]
# ### Nombre de paroles par personnage

# %%
nbr_paroles1 = count(df1['Name'], 'Prénom', 'Nombre de paroles')
nbr_paroles1
# Out:
#             Prénom  Nombre de paroles
# 1             LUKE                252
# 28             HAN                151
# 0         THREEPIO                119
# 21             BEN                 75
# 13            LEIA                 57
# ..             ...                ...
# 15  SECOND OFFICER                  1
# 34     HAN'S VOICE                  1
# 18            BERU                  1
# 31    OFFICER CASS                  1
# 66      TECHNICIAN                  1
#
# [67 rows x 2 columns]

# %%
histo(nbr_paroles1)

# %% [markdown]
# ### Histograme

# %% [markdown]
# ### Nombre d'occurrence de chaque mot

# %%
nbr_mots1 = count(' '.join(df1['paroles_traités']).split(), 'mot', 'Nombre d\'occurrence')
nbr_mots1
# Out:
#            mot  Nombre d'occurrence
# 30       going                   67
# 170       luke                   62
# 23         get                   59
# 61       right                   47
# 21        come                   45
# ...        ...                  ...
# 810    however                    1
# 811   unlikely                    1
# 813    exploit                    1
# 814      refer                    1
# 1548    donate                    1
#
# [1549 rows x 2 columns]

# %% [markdown]
# ### Wordcloud

# %%
wordcloud(D1['paroles_traités'])

# %% [markdown]
# ## The Empire strikes Back

# %%
## impotation des données
df2 = pd.read_csv(getpath(2), sep = ';') 
df2
# Out:
#               Name                                             parole
# 0    CAPTAIN TYPHO  We made it. I guess I was wrong,there was no d...
# 1           PADMÉ                                               Cordé
# 2            CORDÉ                  I'm sorry, m'lady I'm not sure I
# 3          AMIDALA                                        No! No! No!
# 4          AMIDALA                       I should not have come back.
# ..             ...                                                ...
# 879     MACE WINDU                          Where is your apprentice?
# 880        OBI-WAN  On his way back to Naboo. He isescorting Senat...
# 881        OBI-WAN  I must admit without the clones,it would not h...
# 882           YODA                         Victory? Victory, you say?
# 883           YODA                      Not victory, a defeat, it was
#
# [884 rows x 2 columns]

# %%
D2 = magic2(df2)
D2
# Out:
#               Name                                             parole  \
# 0    CAPTAIN TYPHO  We made it. I guess I was wrong,there was no d...
# 1           PADMÉ                                               Cordé
# 2            CORDÉ                  I'm sorry, m'lady I'm not sure I
# 3          AMIDALA                                        No! No! No!
# 4          AMIDALA                       I should not have come back.
# ..             ...                                                ...
# 879     MACE WINDU                          Where is your apprentice?
# 880        OBI-WAN  On his way back to Naboo. He isescorting Senat...
# 881        OBI-WAN  I must admit without the clones,it would not h...
# 882           YODA                         Victory? Victory, you say?
# 883           YODA                      Not victory, a defeat, it was
#
#                                      paroles_traités
# 0                            made guess wrong danger
# ...

# %% [markdown]
# ## indicateurs statistiques

# %%
nbr_paroles2 = count(df2['Name'], 'Prénom', 'Nombre de paroles')
nbr_paroles2
# Out:
#         Prénom  Nombre de paroles
# 17      ANAKIN                191
# 16     OBI-WAN                155
# 9        PADMÉ                 96
# 25       PADME                 65
# 11        YODA                 29
# ..         ...                ...
# 48     OBI-WAM                  1
# 40       JOVAL                  1
# 45  MACE-WINDU                  1
# 44        MACE                  1
# 49      WINDU                   1
#
# [75 rows x 2 columns]

# %% [markdown]
# ## Histograme

# %%
histo(nbr_paroles2)

# %% [markdown]
# ### Nombre d'occurrence de chaque mot

# %%
nbr_mots2 = count(' '.join(df2['paroles_traités']).split(), 'mot', 'Nombre d\'occurrence')
nbr_mots2
# Out:
#                         mot  Nombre d'occurrence
# 214                  master                   69
# 87                     jedi                   50
# 216                   think                   40
# 200                    know                   36
# 77                  senator                   35
# ...                     ...                  ...
# 1076  apprenticelegislators                    1
# 1075                ijoined                    1
# 1074                  eight                    1
# 1073       politicianscould                    1
# 2449                 defeat                    1
#
# [2450 rows x 2 columns]

# %%
wordcloud(D2['paroles_traités'])
